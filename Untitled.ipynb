# %%
import pandas as pd

# %%
df = pd.read_csv("JX Computer Science Curriculum Standards.csv")

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>Subject</th>\n      <th>Domain</th>\n      <th>Sub Domain</th>\n      <th>Standard</th>\n      <th>Cluster</th>\n      <th>Lesson Taught</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Math</td>\n      <td>Year 5</td>\n      <td>Operations and Algebraic Thinking</td>\n      <td>Use parentheses, brackets, or braces in numeri...</td>\n      <td>Write and interpret numerical expressions.</td>\n      <td>Course: Intro to Computer Science With Python,...</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Math</td>\n      <td>Year 5</td>\n      <td>Operations and Algebraic Thinking</td>\n      <td>Write simple expressions that record calculati...</td>\n      <td>Write and interpret numerical expressions.</td>\n      <td>Course: Intro to Computer Science With Python,...</td>\n    </t
# ...
